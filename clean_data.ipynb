# %%
# %pip install pandas matplotlib
# Out:
# Requirement already satisfied: pandas in c:\users\kevin\appdata\local\programs\python\python314\lib\site-packages (3.0.1)
# Requirement already satisfied: matplotlib in c:\users\kevin\appdata\local\programs\python\python314\lib\site-packages (3.10.8)
# Requirement already satisfied: numpy>=2.3.3 in c:\users\kevin\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kevin\appdata\roaming\python\python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\kevin\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kevin\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\kevin\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kevin\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kevin\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\kevin\appdata\roaming\python\python314\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\kevin\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\kevin\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in c:\users\kevin\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
bios = pd.read_csv('bios.csv')
# can also use the raw file link in github repo inside parentheses above   
bios.head()
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
#
#                                            Full name              Used name  \
# 0  François Joseph Marie Antoine "Jean-François"•...  Jean-François•Blanchy
# 1                            Arnaud Benjamin•Boetsch         Arnaud•Boetsch
# 2                        Jean Laurent Robert•Borotra           Jean•Borotra
# 3               Jacques Marie Stanislas Jean•Brugnon        Jacques•Brugnon
# 4                                 Henry Albert•Canet           Albert•Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3            11 May 1895 in Paris VIIIe, Paris (FRA)
# 4         17 April 1878 in Wandsworth, England (GBR)
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France           1
# 1                                                NaN  France           2
# 2  17 July 1994 in Arbonne, Pyrénées-Atlantiques ...  France           3
# 3              20 March 1978 in Monaco, Monaco (MON)  France           4
# 4            25 July 1930 in Paris VIIe, Paris (FRA)  France           5
#
#      Measurements                         Affiliations  \
# 0             NaN                                  NaN
# 1  183 cm / 76 kg   Racing Club de France, Paris (FRA)
# 2  183 cm / 76 kg                     TCP, Paris (FRA)
# 3  168 cm / 64 kg  Sporting club de Paris, Paris (FRA)
# 4             NaN                     TCP, Paris (FRA)
#
#                                 Nick/petnames Title(s) Other names  \
# 0                                         NaN      NaN         NaN
# 1                                         NaN      NaN         NaN
# 2  Le Basque Bondissant (The Bounding Basque)      NaN         NaN
# 3                                        Toto      NaN         NaN
# 4                                         NaN      NaN         NaN
#
#   Nationality Original name Name order
# 0         NaN           NaN        NaN
# 1         NaN           NaN        NaN
# 2         NaN           NaN        NaN
# 3         NaN           NaN        NaN
# 4         NaN           NaN        NaN

# %% [markdown]
# ### What Should We Clean Up?

# %% [markdown]
# ### Bios
# - [x] Remove bullet points in Used name column
# - [x] Split height/weight in Measurements column
# - [x] Parse out dates from `Born` and `Died` columns
# - [x] Parse out city, region, country from `Born` column
# - [ ] Remove extra columns
#
# ### Results
# - [x] Isolate Number from Position
# - [ ]
# - [ ]
# - [ ]
# - [ ] Remove extra columns (ex: unnamed)

# %%
df = bios.copy()

# %% [markdown]
# ## Bios

# %% [markdown]
# ### Remove Bullet Points In Used names

# %%
# display number of records in dataframe and the number of records that contain a bullet point
print(len(df), len(df[df['Used name'].str.contains("•")]))
# Out:
# 145500 145500

# %%
df['Name'] = df['Used name'].str.replace("•", " ")
# df.head()

# %% [markdown]
# ### Split the Measurements column into separate columns for height and weight

# %%
# Split the Measurements column into separate columns for height and weight
df[['Height_cm', 'Weight_kg']] = df['Measurements'].str.split(' / ', expand=True) # expand=True allows us to split into separate columns
df.head()
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
#
#                                            Full name              Used name  \
# 0  François Joseph Marie Antoine "Jean-François"•...  Jean-François•Blanchy
# 1                            Arnaud Benjamin•Boetsch         Arnaud•Boetsch
# 2                        Jean Laurent Robert•Borotra           Jean•Borotra
# 3               Jacques Marie Stanislas Jean•Brugnon        Jacques•Brugnon
# 4                                 Henry Albert•Canet           Albert•Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3            11 May 1895 in Paris VIIIe, Paris (FRA)
# 4         17 April 1878 in Wandsworth, England (GBR)
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France           1
# 1                                                NaN  France           2
# 2  17 July 1994 in Arbonne, Pyrénées-Atlantiques ...  France           3
# 3              20 March 1978 in Monaco, Monaco (MON)  France           4
# 4            25 July 1930 in Paris VIIe, Paris (FRA)  France           5
#
#      Measurements                         Affiliations  \
# 0             NaN                                  NaN
# 1  183 cm / 76 kg   Racing Club de France, Paris (FRA)
# 2  183 cm / 76 kg                     TCP, Paris (FRA)
# 3  168 cm / 64 kg  Sporting club de Paris, Paris (FRA)
# 4             NaN                     TCP, Paris (FRA)
#
#                                 Nick/petnames Title(s) Other names  \
# 0                                         NaN      NaN         NaN
# 1                                         NaN      NaN         NaN
# 2  Le Basque Bondissant (The Bounding Basque)      NaN         NaN
# 3                                        Toto      NaN         NaN
# 4                                         NaN      NaN         NaN
#
#   Nationality Original name Name order                   Name Height_cm  \
# 0         NaN           NaN        NaN  Jean-François Blanchy       NaN
# 1         NaN           NaN        NaN         Arnaud Boetsch    183 cm
# 2         NaN           NaN        NaN           Jean Borotra    183 cm
# 3         NaN           NaN        NaN        Jacques Brugnon    168 cm
# 4         NaN           NaN        NaN           Albert Canet       NaN
#
#   Weight_kg
# 0       NaN
# 1     76 kg
# 2     76 kg
# 3     64 kg
# 4       NaN

# %%
## Small example to test out the code before applying to the full dataset
small_data = pd.DataFrame(['183 cm', '180 cm / 150 kg', '190 cm / 80 kg', '100 kg'], columns=['Measurements'])

# split around slash, allowing optional spaces
small_data[['Height_cm', 'Weight_kg']] = small_data['Measurements'].str.split('/', expand=True)

# fill missing weight with the height field (assign result back)
small_data['Weight_kg'] = small_data['Weight_kg'].fillna(small_data['Height_cm'])

# remove "cm" and "kg" and convert to numeric, coercing errors to NaN
small_data['Height_cm'] = pd.to_numeric(small_data['Height_cm'].str.strip(' cm'), errors='coerce') 
small_data['Weight_kg'] = pd.to_numeric(small_data['Weight_kg'].str.strip(' kg'), errors='coerce')

small_data
# Out:
#       Measurements  Height_cm  Weight_kg
# 0           183 cm      183.0        NaN
# 1  180 cm / 150 kg      180.0      150.0
# 2   190 cm / 80 kg      190.0       80.0
# 3           100 kg        NaN      100.0

# %%
# check to make sure all values have '/'
# df[~df['Measurements'].str.contains("/", na=False) & df['Measurements'].notna()] # this will show any records where Measurements does not contain '/' and is not null

# %%
# remove the "cm" and "kg" units from the height and weight columns
df['Height_cm'] = pd.to_numeric(df['Height_cm'].str.strip(' cm'), errors='coerce') 
df['Weight_kg'] = pd.to_numeric(df['Weight_kg'].str.strip(' kg'), errors='coerce')

# %%
df.head()
df.sort_values('Height_cm', ascending=False)
# Out:
#                                     Roles     Sex  \
# 89070   Competed in Olympic Games • Other    Male
# 6978            Competed in Olympic Games    Male
# 5781            Competed in Olympic Games    Male
# 89075           Competed in Olympic Games    Male
# 120266          Competed in Olympic Games    Male
# ...                                   ...     ...
# 145490          Competed in Olympic Games    Male
# 145491          Competed in Olympic Games    Male
# 145492          Competed in Olympic Games    Male
# 145493          Competed in Olympic Games  Female
# 145499        Non-starter • Administrator    Male
#
#                              Full name              Used name  \
# 89070                         Yao•Ming               Yao•Ming
# 6978             Arvydas Romas•Sabonis        Arvydas•Sabonis
# 5781     Thomas Loren "Tommy"•Burleson         Tommy•Burleson
# 89075         Roberto•Dueñas Hernández         Roberto•Dueñas
# 120266                    Zhang•Zhaoxu           Zhang•Zhaoxu
# ...                                ...                    ...
# 145490                     Sin•Ye-Chan            Sin•Ye-Chan
# 145491                   Matthew•Wepke          Matthew•Wepke
# 145492  Carlos•García-Ordóñez Montalvo  Carlos•García-Ordóñez
# 145493    Landysh Ilsurovna•Falyakhova     Landysh•Falyakhova
# 145499   William Berge "Bill"•Phillips          Bill•Phillips
#
#                                                      Born  \
# 89070   12 September 1980 in Xuhui District, Shanghai ...
# 6978             19 December 1964 in Kaunas, Kaunas (LTU)
# 5781    24 February 1952 in Crossnore, North Carolina ...
# 89075             1 November 1975 in Madrid, Madrid (ESP)
# 120266        18 November 1987 in Binzhou, Shandong (CHN)
# ...                                                   ...
# 145490                                       13 June 1995
# 145491                                    5 December 1989
# 145492  24 April 1927 in La Habana (Havana), Ciudad de...
# 145493  31 August 1998 in Dva Polya Artash, Respublika...
# 145499  15 July 1913 in Dulwich Hill, New South Wales ...
#
#                                                     Died  \
# 89070                                                NaN
# 6978                                                 NaN
# 5781                                                 NaN
# 89075                                                NaN
# 120266                                               NaN
# ...                                                  ...
# 145490                                               NaN
# 145491                                               NaN
# 145492          24 November 2019 in Miami, Florida (USA)
# 145493                                               NaN
# 145499  20 October 2003 in Sydney, New South Wales (AUS)
#
#                                NOC  athlete_id     Measurements  \
# 89070   People's Republic of China       89782  226 cm / 141 kg
# 6978        Lithuania Soviet Union        7013  223 cm / 122 kg
# 5781                 United States        5804  223 cm / 102 kg
# 89075                        Spain       89787  221 cm / 137 kg
# 120266  People's Republic of China      122147  221 cm / 110 kg
# ...                            ...         ...              ...
# 145490           Republic of Korea      149217              NaN
# 145491                     Jamaica      149218              NaN
# 145492                        Cuba      149219              NaN
# 145493                         ROC      149220              NaN
# 145499                   Australia      149814              NaN
#
#                                              Affiliations Nick/petnames  \
# 89070   Shanghai Sharks, Shanghai (CHN) / Houston Rock...           NaN
# 6978    Žalgiris Kaunas, Kaunas (LTU) / Real Madrid, M...         Sabas
# 5781                     NC State Wolfpack, Raleigh (USA)           NaN
# 89075                       FC Barcelona, Barcelona (ESP)           NaN
# 120266                    Shanghai Sharks, Shanghai (CHN)           NaN
# ...                                                   ...           ...
# 145490                                                NaN           NaN
# 145491                                                NaN           NaN
# 145492                                                NaN           NaN
# 145493        SKIF Nizhny Novgorod, Nizhny Novgorod (RUS)           NaN
# 145499                                                NaN           NaN
#
#        Title(s)                                   Other names Nationality  \
# 89070       NaN                                           NaN         NaN
# 6978        NaN  Arvidas Romas Sabonis, Арвидас Ромас Сабонис   Lithuania
# 5781        NaN                                           NaN         NaN
# 89075       NaN                                           NaN         NaN
# 120266      NaN                                           NaN         NaN
# ...         ...                                           ...         ...
# 145490      NaN                                  Shin Ye-Chan         NaN
# 145491      NaN                                           NaN         NaN
# 145492      NaN                                           NaN         NaN
# 145493      NaN                                           NaN         NaN
# 145499      NaN                                           NaN         NaN
#
#                      Original name Name order                   Name  \
# 89070                          姚•明   Oriental               Yao Ming
# 6978                           NaN        NaN        Arvydas Sabonis
# 5781                           NaN        NaN         Tommy Burleson
# 89075                          NaN        NaN         Roberto Dueñas
# 120266                        张•兆旭   Oriental           Zhang Zhaoxu
# ...                            ...        ...                    ...
# 145490                        신•예찬   Oriental            Sin Ye-Chan
# 145491                         NaN        NaN          Matthew Wepke
# 145492                         NaN        NaN  Carlos García-Ordóñez
# 145493  Ландыш Ильсуровна•Фаляхова        NaN     Landysh Falyakhova
# 145499                         NaN        NaN          Bill Phillips
#
#         Height_cm  Weight_kg
# 89070       226.0      141.0
# 6978        223.0      122.0
# 5781        223.0      102.0
# 89075       221.0      137.0
# 120266      221.0      110.0
# ...           ...        ...
# 145490        NaN        NaN
# 145491        NaN        NaN
# 145492        NaN        NaN
# 145493        NaN        NaN
# 145499        NaN        NaN
#
# [145500 rows x 19 columns]

# %% [markdown]
# ### Parse out dates from `Born` and `Died`

# %%
date_pattern = r'(\d+ \w+ \d{4} | \d{4})' # + = 1 or more; {number} specifies exact number of digits; \w+ matches the month name; parentheses capture the date as a group
# df['Born_Date'] = df['Born'].str.extract(date_pattern) 

df[~df['Born'].str.match(date_pattern, na=False) & df['Born'].notna()] # check for any records where born_date is null but Born is not null, which would indicate a parsing issue
# Out:
#                             Roles     Sex              Full name  \
# 91      Competed in Olympic Games    Male  Lionel Hunter•Escombe
# 164     Competed in Olympic Games  Female         Helen•Amankwah
# 165     Competed in Olympic Games  Female  Patricia Akosua•Offel
# 166     Competed in Olympic Games  Female  Patience Abena•Opokua
# 167     Competed in Olympic Games    Male          Winifred•Addy
# ...                           ...     ...                    ...
# 145483  Competed in Olympic Games  Female                Feng•He
# 145486                Non-starter    Male     Dmitry•Karlagachev
# 145489  Competed in Olympic Games    Male             Ye•Jielong
# 145490  Competed in Olympic Games    Male            Sin•Ye-Chan
# 145491  Competed in Olympic Games    Male          Matthew•Wepke
#
#                  Used name                                Born  \
# 91          Lionel•Escombe  1876 in Natal, KwaZulu-Natal (RSA)
# 164         Helen•Amankwah                       13 April 1964
# 165         Patricia•Offel                    19 December 1971
# 166        Patience•Opokua                        17 June 1969
# 167          Winifred•Addy                       17 March 1973
# ...                    ...                                 ...
# 145483             Feng•He                       31 March 2004
# 145486  Dmitry•Karlagachev                     13 October 1998
# 145489          Ye•Jielong                        2 March 2000
# 145490         Sin•Ye-Chan                        13 June 1995
# 145491       Matthew•Wepke                     5 December 1989
#
#                                                Died  \
# 91      15 October 1914 in Brentford, England (GBR)
# 164                                             NaN
# 165                                             NaN
# 166                                             NaN
# 167                                             NaN
# ...                                             ...
# 145483                                          NaN
# 145486                                          NaN
# 145489                                          NaN
# 145490                                          NaN
# 145491                                          NaN
#
#                                NOC  athlete_id Measurements Affiliations  \
# 91                   Great Britain          92          NaN          NaN
# 164                          Ghana         165          NaN          NaN
# 165                          Ghana         166       120 kg          NaN
# 166                          Ghana         167          NaN          NaN
# 167                          Ghana         168          NaN          NaN
# ...                            ...         ...          ...          ...
# 145483  People's Republic of China      149210          NaN          NaN
# 145486                         ROC      149213          NaN          NaN
# 145489  People's Republic of China      149216          NaN          NaN
# 145490           Republic of Korea      149217          NaN          NaN
# 145491                     Jamaica      149218          NaN          NaN
#
#        Nick/petnames Title(s)   Other names Nationality Original name  \
# 91               NaN      NaN           NaN         NaN           NaN
# 164              NaN      NaN           NaN         NaN           NaN
# 165              NaN      NaN           NaN         NaN           NaN
# 166              NaN      NaN           NaN         NaN           NaN
# 167              NaN      NaN           NaN         NaN           NaN
# ...              ...      ...           ...         ...           ...
# 145483           NaN      NaN           NaN         NaN           冯•贺
# 145486           NaN      NaN           NaN         NaN           NaN
# 145489           NaN      NaN           NaN         NaN          叶•杰龙
# 145490           NaN      NaN  Shin Ye-Chan         NaN          신•예찬
# 145491           NaN      NaN           NaN         NaN           NaN
#
#        Name order                Name  Height_cm  Weight_kg
# 91            NaN      Lionel Escombe        NaN        NaN
# 164           NaN      Helen Amankwah        NaN        NaN
# 165           NaN      Patricia Offel        NaN        NaN
# 166           NaN     Patience Opokua        NaN        NaN
# 167           NaN       Winifred Addy        NaN        NaN
# ...           ...                 ...        ...        ...
# 145483   Oriental             Feng He        NaN        NaN
# 145486        NaN  Dmitry Karlagachev        NaN        NaN
# 145489   Oriental          Ye Jielong        NaN        NaN
# 145490   Oriental         Sin Ye-Chan        NaN        NaN
# 145491        NaN       Matthew Wepke        NaN        NaN
#
# [23746 rows x 19 columns]

# %%
date_pattern = r'(\d+ \w+ \d{4} | \d{4})'

df['Born_Date'] = pd.to_datetime(df['Born'].str.extract(date_pattern)[0], format = 'mixed', errors='coerce') # extract the date in format "day month year" and convert to datetime, coercing errors to NaT
df['Died_Date'] = pd.to_datetime(df['Died'].str.extract(date_pattern)[0], format = 'mixed', errors='coerce')

# extract just the year from the Born column
# df['Born_Year'] = df['Born'].str.extract(r'(\d{4})')[0] # extract just the year from the Born column
# df['Born_Year'] = pd.to_numeric(df['Born_Year'])

# %%
# df[df.Born_Date.dt.year==2000]
# df = df.drop('born_date', axis=1)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 21 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Roles          145500 non-null  str
#  1   Sex            145500 non-null  str
#  2   Full name      145500 non-null  str
#  3   Used name      145500 non-null  str
#  4   Born           143772 non-null  str
#  5   Died           34042 non-null   str
#  6   NOC            145499 non-null  str
#  7   athlete_id     145500 non-null  int64
#  8   Measurements   107833 non-null  str
#  9   Affiliations   95832 non-null   str
#  10  Nick/petnames  9145 non-null    str
#  11  Title(s)       399 non-null     str
#  12  Other names    7167 non-null    str
#  13  Nationality    8259 non-null    str
#  14  Original name  30739 non-null   str
#  15  Name order     7844 non-null    str
#  16  Name           145500 non-null  str
#  17  Height_cm      106651 non-null  float64
#  18  Weight_kg      102070 non-null  float64
#  19  Born_Date      141819 non-null  datetime64[us]
#  20  Died_Date      32857 non-null   datetime64[us]
# dtypes: datetime64[us](2), float64(2), int64(1), str(16)
# memory usage: 23.3 MB

# %%
df.head()
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
#
#                                            Full name              Used name  \
# 0  François Joseph Marie Antoine "Jean-François"•...  Jean-François•Blanchy
# 1                            Arnaud Benjamin•Boetsch         Arnaud•Boetsch
# 2                        Jean Laurent Robert•Borotra           Jean•Borotra
# 3               Jacques Marie Stanislas Jean•Brugnon        Jacques•Brugnon
# 4                                 Henry Albert•Canet           Albert•Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3            11 May 1895 in Paris VIIIe, Paris (FRA)
# 4         17 April 1878 in Wandsworth, England (GBR)
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France           1
# 1                                                NaN  France           2
# 2  17 July 1994 in Arbonne, Pyrénées-Atlantiques ...  France           3
# 3              20 March 1978 in Monaco, Monaco (MON)  France           4
# 4            25 July 1930 in Paris VIIe, Paris (FRA)  France           5
#
#      Measurements                         Affiliations  ... Title(s)  \
# 0             NaN                                  NaN  ...      NaN
# 1  183 cm / 76 kg   Racing Club de France, Paris (FRA)  ...      NaN
# 2  183 cm / 76 kg                     TCP, Paris (FRA)  ...      NaN
# 3  168 cm / 64 kg  Sporting club de Paris, Paris (FRA)  ...      NaN
# 4             NaN                     TCP, Paris (FRA)  ...      NaN
#
#   Other names Nationality Original name Name order                   Name  \
# 0         NaN         NaN           NaN        NaN  Jean-François Blanchy
# 1         NaN         NaN           NaN        NaN         Arnaud Boetsch
# 2         NaN         NaN           NaN        NaN           Jean Borotra
# 3         NaN         NaN           NaN        NaN        Jacques Brugnon
# 4         NaN         NaN           NaN        NaN           Albert Canet
#
#   Height_cm  Weight_kg  Born_Date  Died_Date
# 0       NaN        NaN 1886-12-12 1960-10-02
# 1     183.0       76.0 1969-04-01        NaT
# 2     183.0       76.0 1898-08-13 1994-07-17
# 3     168.0       64.0 1895-05-11 1978-03-20
# 4       NaN        NaN 1878-04-17 1930-07-25
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Parse Out City, Region, Country

# %%
location_pattern = r'in ([\w\s-]+), ([\w\s-]+) \((\w+)\)'
df['Born'].str.extract(location_pattern)
# Out:
#                    0                     1    2
# 0           Bordeaux               Gironde  FRA
# 1             Meulan              Yvelines  FRA
# 2           Biarritz  Pyrénées-Atlantiques  FRA
# 3        Paris VIIIe                 Paris  FRA
# 4         Wandsworth               England  GBR
# ...              ...                   ...  ...
# 145495         Serov            Sverdlovsk  RUS
# 145496           NaN                   NaN  NaN
# 145497        Kotlas           Arkhangelsk  RUS
# 145498         Niort           Deux-Sèvres  FRA
# 145499  Dulwich Hill       New South Wales  AUS
#
# [145500 rows x 3 columns]

# %%
df[['Born_City','Born_Region','Born_Country']] = df['Born'].str.extract(location_pattern, expand=True)

# %%
# pd.set_option('display.max_colwidth', None) # to display all columns in the dataframe

df.value_counts('Born_Region', ascending=False).head(10)
df.value_counts('Born_City', ascending=False).head(10)
# Out:
# Born_City
# Budapest          1378
# Oslo               708
# Stockholm          629
# Toronto            579
# Buenos Aires       538
# Sydney             497
# Montréal           468
# Berlin             467
# Helsinki           439
# Rio de Janeiro     433
# Name: count, dtype: int64

# %% [markdown]
# ### Remove Any Unnecessary Columns

# %%
df.columns
# Out:
# Index(['Roles', 'Sex', 'Full name', 'Used name', 'Born', 'Died', 'NOC',
#        'athlete_id', 'Measurements', 'Affiliations', 'Nick/petnames',
#        'Title(s)', 'Other names', 'Nationality', 'Original name', 'Name order',
#        'Name', 'Height_cm', 'Weight_kg', 'Born_Date', 'Died_Date', 'Born_City',
#        'Born_Region', 'Born_Country'],
#       dtype='str')

# %%
Kept_Columns = ['athlete_id','Name', 'Born_Date', 'Born_City', 'Born_Region', 
                'Born_Country', 'NOC', 'Height_cm', 'Weight_kg', 'Died_Date']

df_cleaned = df[Kept_Columns]

# %%
df_cleaned.head()
# Out:
#    athlete_id                   Name  Born_Date    Born_City  \
# 0           1  Jean-François Blanchy 1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch 1969-04-01       Meulan
# 2           3           Jean Borotra 1898-08-13     Biarritz
# 3           4        Jacques Brugnon 1895-05-11  Paris VIIIe
# 4           5           Albert Canet 1878-04-17   Wandsworth
#
#             Born_Region Born_Country     NOC  Height_cm  Weight_kg  Died_Date
# 0               Gironde          FRA  France        NaN        NaN 1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0        NaT
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0 1994-07-17
# 3                 Paris          FRA  France      168.0       64.0 1978-03-20
# 4               England          GBR  France        NaN        NaN 1930-07-25

# %%
df_cleaned.to_csv('./clean-data/bios.csv', index=False)

# %% [markdown]
# ## Results

# %%
results = pd.read_csv('./Results/results.csv')
results.head()
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_5480\1590646784.py:1: DtypeWarning: Columns (0: Nationality) have mixed types. Specify dtype option on import or set low_memory=False.
#   results = pd.read_csv('./Results/results.csv')
#                   Games                     Event             Team  Pos Medal  \
# 0  1912 Summer Olympics    Singles, Men (Olympic)              NaN  =17   NaN
# 1  1912 Summer Olympics    Doubles, Men (Olympic)   Jean Montariol  DNS   NaN
# 2  1920 Summer Olympics    Singles, Men (Olympic)              NaN  =32   NaN
# 3  1920 Summer Olympics  Doubles, Mixed (Olympic)  Jeanne Vaussard   =8   NaN
# 4  1920 Summer Olympics    Doubles, Men (Olympic)  Jacques Brugnon    4   NaN
#
#                       As  athlete_id  NOC Discipline Nationality  Unnamed: 7
# 0  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
# 1  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
# 2  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
# 3  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
# 4  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN

# %% [markdown]
# ### Extract Number from Position

# %%
results['place'] = results['Pos'].str.extract(r'(\d+)') # extract the numeric part of the Pos column

# %%
results.head()
# Out:
#                   Games                     Event             Team  Pos Medal  \
# 0  1912 Summer Olympics    Singles, Men (Olympic)              NaN  =17   NaN
# 1  1912 Summer Olympics    Doubles, Men (Olympic)   Jean Montariol  DNS   NaN
# 2  1920 Summer Olympics    Singles, Men (Olympic)              NaN  =32   NaN
# 3  1920 Summer Olympics  Doubles, Mixed (Olympic)  Jeanne Vaussard   =8   NaN
# 4  1920 Summer Olympics    Doubles, Men (Olympic)  Jacques Brugnon    4   NaN
#
#                       As  athlete_id  NOC Discipline Nationality  Unnamed: 7  \
# 0  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
# 1  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
# 2  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
# 3  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
# 4  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
#
#   place
# 0    17
# 1   NaN
# 2    32
# 3     8
# 4     4

# %% [markdown]
# ### Remove Unnecessary Columns

# %%
results.drop(columns=['Unnamed: 7'], inplace=True)
results.head()
# Out:
#                   Games                     Event             Team  Pos Medal  \
# 0  1912 Summer Olympics    Singles, Men (Olympic)              NaN  =17   NaN
# 1  1912 Summer Olympics    Doubles, Men (Olympic)   Jean Montariol  DNS   NaN
# 2  1920 Summer Olympics    Singles, Men (Olympic)              NaN  =32   NaN
# 3  1920 Summer Olympics  Doubles, Mixed (Olympic)  Jeanne Vaussard   =8   NaN
# 4  1920 Summer Olympics    Doubles, Men (Olympic)  Jacques Brugnon    4   NaN
#
#                       As  athlete_id  NOC Discipline Nationality place
# 0  Jean-François Blanchy           1  FRA     Tennis         NaN    17
# 1  Jean-François Blanchy           1  FRA     Tennis         NaN   NaN
# 2  Jean-François Blanchy           1  FRA     Tennis         NaN    32
# 3  Jean-François Blanchy           1  FRA     Tennis         NaN     8
# 4  Jean-François Blanchy           1  FRA     Tennis         NaN     4
